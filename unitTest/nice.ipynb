# %%
from ultralytics import YOLO
import cv2
import numpy as np
import time

# YOLO 신뢰도 임계값 및 거리 경고 임계값 설정
CONF_THRESHOLD = 0.3
DIST_THRESHOLD = 1200  # cm 단위 거리 경고 기준
FOCAL_LENGTH = 400  # 카메라 초점 거리
RESIZE_WIDTH = 1280
RESIZE_HEIGHT = 720

# 차선 영역을 나타내는 네 꼭짓점 비율 좌표 (좌측 하단 → 우측 하단 → 우측 상단 → 좌측 상단)
LANE_POLYGON_VERTICES = [
    (0.2, 1.0), (0.8, 1.0), (0.6, 0.6), (0.4, 0.6)
]

# 클래스별 실제 객체 높이 (cm)
KNOWN_HEIGHTS = {
    0: 160,   # 사람
    2: 150,   # 자동차
    3: 100,   # 오토바이
    5: 350,   # 버스
    7: 350    # 트럭
}

# 객체 종류별 표시 색상
CLASS_COLORS = {
    2: (0, 255, 0),    # 자동차
    5: (255, 255, 0),  # 버스
    7: (255, 0, 255)   # 트럭
}

# 유효 클래스 ID 리스트 생성
VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())

# YOLO 모델 로드
model = YOLO(r"C:\Users\USER\Downloads\notyet\best.pt")

# 비디오 로드
video_path = r"C:\Users\USER\Downloads\notyet\police.mp4"
cap = cv2.VideoCapture(video_path)

# 결과 저장용 비디오 객체 생성
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))

# 차선 영역 폴리곤 좌표 계산 함수
def detect_lane_area(frame):
    h, w = frame.shape[:2]
    polygon = np.array([[(int(w * x), int(h * y)) for (x, y) in LANE_POLYGON_VERTICES]])
    return polygon[0]

# 원근 변환 행렬 계산 함수
def get_perspective_transform_matrix(frame):
    h, w = frame.shape[:2]
    src_pts = np.float32([[w * x, h * y] for (x, y) in LANE_POLYGON_VERTICES])
    dst_pts = np.float32([[0, h], [w, h], [w, 0], [0, 0]])
    return cv2.getPerspectiveTransform(src_pts, dst_pts)

# 경고 카운터 및 원근 변환 행렬 초기화
warning_counter = 3
M = None

# 배경이 있는 텍스트 출력 함수
def draw_text_with_background(img, text, org, font, scale, color, thickness):
    (tw, th), base = cv2.getTextSize(text, font, scale, thickness)
    x, y = org
    cv2.rectangle(img, (x, y - th - base), (x + tw + 4, y + base), (0, 0, 0), -1)
    cv2.putText(img, text, org, font, scale, color, thickness)

# 프레임 루프 시작
while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (RESIZE_WIDTH, RESIZE_HEIGHT))

    # 최초 프레임에서 원근 변환 행렬 계산
    if M is None:
        M = get_perspective_transform_matrix(frame)

    # 객체 탐지 실행
    results = model(frame, conf=CONF_THRESHOLD, iou=0.5)
    annotated_frame = results[0].plot()  # 기본 탐지 시각화
    lane_polygon = detect_lane_area(frame)  # 차선 영역 폴리곤 계산
    collision_warning = False

    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf.item())
        class_id = int(box.cls.item())
        pixel_height = y2 - y1

        # 너무 작은 객체는 무시
        if pixel_height < 5:
            continue

        # 객체 바닥 중심점 계산
        center_y = y2 - 0.2 * (y2 - y1)
        center = np.array([[(x1 + x2) / 2, center_y]], dtype=np.float32)
        is_inside = cv2.pointPolygonTest(lane_polygon, tuple(center[0]), False)

        if class_id in VALID_CLASS_IDS and conf > CONF_THRESHOLD and pixel_height > 20:
            # 중심점에 대해 원근 변환 수행
            center_warped = cv2.perspectiveTransform(np.array([center]), M)[0][0]

            # 거리 보정 계산
            known_height = KNOWN_HEIGHTS.get(class_id, 170)
            dist_pixel = (known_height * FOCAL_LENGTH) / pixel_height
            warped_y = center_warped[1]
            dist_y = DIST_THRESHOLD * (1 - warped_y / RESIZE_HEIGHT)
            dist_y = max(50, dist_y)

            # 최종 거리 (픽셀 기반, 보정 기반 가중 평균)
            distance_cm = dist_pixel * 0.7 + dist_y * 0.3
            distance_m = distance_cm / 100

            # 경고 여부 판단
            if distance_cm < DIST_THRESHOLD:
                collision_warning = True
                box_color = (0, 0, 255)
                thickness = 3
            else:
                box_color = CLASS_COLORS.get(class_id, (255, 255, 255))
                thickness = 2

            # 바운딩 박스 및 거리 표시
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, thickness)
            dist_label = f"{distance_m:.1f}m"
            draw_text_with_background(annotated_frame, dist_label, (x1, y2 + 25),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)

            # 중심점 표시
            cv2.circle(annotated_frame, (int(center_warped[0]), int(center_warped[1])),
                       5, (255, 0, 0), -1)

    # 경고 텍스트 점등 지속 시간 조절
    warning_counter = min(warning_counter + 5, 30) if collision_warning else max(warning_counter - 1, 0)

    # 경고 시 텍스트 출력
    if warning_counter > 0:
        h, w = frame.shape[:2]
        draw_text_with_background(annotated_frame, "⚠ Forward Collision Warning ⚠",
                                  (int(w * 0.15), 60),
                                  cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

    # 차선 영역 폴리곤 시각화
    cv2.polylines(annotated_frame, [lane_polygon], isClosed=True,
                  color=(0, 255, 255), thickness=2)

    # 시점 변환된 차선을 다시 원래 좌표계로 투영 후 시각화
    lane_poly_np = np.array([lane_polygon], dtype=np.float32)
    warped_lane = cv2.perspectiveTransform(lane_poly_np, M)
    reprojected_lane = cv2.perspectiveTransform(warped_lane, np.linalg.inv(M))
    cv2.polylines(annotated_frame, [np.int32(reprojected_lane)], isClosed=True,
                  color=(0, 150, 255), thickness=2)

    # FPS 계산 및 표시
    fps = 1.0 / (time.time() - start_time)
    cv2.putText(annotated_frame, f"FPS: {fps:.1f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    # 프레임 저장 및 출력
    out.write(annotated_frame)
    cv2.imshow("YOLO + Collision Warning + Warped Lane", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 자원 해제
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 38
#      35 VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())
#      37 # YOLO 모델 로드
# ---> 38 model = YOLO(r"C:\Users\USER\Downloads\notyet\best.pt")
#      40 # 비디오 로드
#      41 video_path = r"C:\Users\USER\Downloads\notyet\police.mp4"
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/models/yolo/model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      81         from ultralytics import RTDETR
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:151, in Model.__init__(self, model, task, verbose)
#     149     self._new(model, task=task, verbose=verbose)
#     150 else:
# --> 151     self._load(model, task=task)
#     153 # Delete super().training for accessing self.model.training
#     154 del self.training
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/engine/model.py:295, in Model._load(self, weights, task)
#     292 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     294 if str(weights).rpartition(".")[-1] == "pt":
# --> 295     self.model, self.ckpt = attempt_load_one_weight(weights)
#     296     self.task = self.model.task
#     297     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:1548, in attempt_load_one_weight(weight, device, inplace, fuse)
#    1534 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#    1535     """
#    1536     Load a single model weights.
#    1537
#    (...)
#    1546         ckpt (dict): Model checkpoint dictionary.
#    1547     """
# -> 1548     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1549     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1550     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/nn/tasks.py:1446, in torch_safe_load(weight, safe_only)
#    1444                 ckpt = torch.load(f, pickle_module=safe_pickle)
#    1445         else:
# -> 1446             ckpt = torch.load(file, map_location="cpu")
#    1448 except ModuleNotFoundError as e:  # e.name is missing module name
#    1449     if e.name == "models":
#
# File /opt/anaconda3/lib/python3.12/site-packages/ultralytics/utils/patches.py:117, in torch_load(*args, **kwargs)
#     114 if TORCH_1_13 and "weights_only" not in kwargs:
#     115     kwargs["weights_only"] = False
# --> 117 return _torch_load(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\USER\\Downloads\\notyet\\best.pt'

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import time

# 설정 상수
CONF_THRESHOLD = 0.3
DIST_THRESHOLD = 1200  # cm
FOCAL_LENGTH = 400
RESIZE_WIDTH = 1280
RESIZE_HEIGHT = 720

LANE_POLYGON_VERTICES = [
    (0.2, 1.0), (0.8, 1.0), (0.6, 0.6), (0.4, 0.6)
]

KNOWN_HEIGHTS = {
    0: 160,  # 사람
    2: 150,  # 자동차
    3: 100,  # 오토바이
    5: 350,  # 버스
    7: 350   # 트럭
}

CLASS_COLORS = {
    2: (0, 255, 0),
    5: (255, 255, 0),
    7: (255, 0, 255)
}

VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())

model = YOLO("/home/hkit/Downloads/3team3/best.pt")

cap = cv2.VideoCapture("/home/hkit/Downloads/3team3/서성네거리 11중 추돌사고 당시 블랙박스 영상.mp4")
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))

def detect_lane_area(frame):
    h, w = frame.shape[:2]
    polygon = np.array([[(int(w * x), int(h * y)) for (x, y) in LANE_POLYGON_VERTICES]])
    return polygon[0]

def get_perspective_transform_matrix(frame):
    h, w = frame.shape[:2]
    src_pts = np.float32([[w * x, h * y] for (x, y) in LANE_POLYGON_VERTICES])
    dst_pts = np.float32([[0, h], [w, h], [w, 0], [0, 0]])
    return cv2.getPerspectiveTransform(src_pts, dst_pts)

def draw_text_with_background(img, text, org, font, scale, color, thickness):
    (tw, th), base = cv2.getTextSize(text, font, scale, thickness)
    x, y = org
    cv2.rectangle(img, (x, y - th - base), (x + tw + 4, y + base), (0, 0, 0), -1)
    cv2.putText(img, text, org, font, scale, color, thickness)

def process_detections(results, lane_polygon, M):
    collision_warning = False
    annotated_frame = results[0].plot()

    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf.item())
        class_id = int(box.cls.item())
        pixel_height = y2 - y1

        if pixel_height < 5:
            continue

        center_y = y2 - 0.2 * (y2 - y1)
        center = np.array([[(x1 + x2) / 2, center_y]], dtype=np.float32)
        is_inside = cv2.pointPolygonTest(lane_polygon, tuple(center[0]), False)

        if class_id in VALID_CLASS_IDS and conf > CONF_THRESHOLD and pixel_height > 20:
            center_warped = cv2.perspectiveTransform(np.array([center]), M)[0][0]
            known_height = KNOWN_HEIGHTS.get(class_id, 170)
            dist_pixel = (known_height * FOCAL_LENGTH) / pixel_height
            warped_y = center_warped[1]
            dist_y = DIST_THRESHOLD * (1 - warped_y / RESIZE_HEIGHT)
            dist_y = max(50, dist_y)

            distance_cm = dist_pixel * 0.7 + dist_y * 0.3
            distance_m = distance_cm / 100

            # 원본 경고 조건 그대로 유지
            if distance_cm < DIST_THRESHOLD:
                collision_warning = True
                box_color = (0, 0, 255)
                thickness = 3
            else:
                box_color = CLASS_COLORS.get(class_id, (255, 255, 255))
                thickness = 2

            # 바운딩 박스 및 거리 표시 (항상 표시)
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, thickness)
            dist_label = f"{distance_m:.1f}m"
            class_label = model.model.names[class_id] if hasattr(model.model, 'names') else str(class_id)
            draw_text_with_background(annotated_frame, dist_label, (x1, y2 + 25),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)

            # 중심점 표시
            cv2.circle(annotated_frame, (int(center_warped[0]), int(center_warped[1])),
                       5, (255, 0, 0), -1)

    return annotated_frame, collision_warning

warning_counter = 3
M = None

while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (RESIZE_WIDTH, RESIZE_HEIGHT))

    if M is None:
        M = get_perspective_transform_matrix(frame)

    results = model(frame, conf=CONF_THRESHOLD, iou=0.5)
    lane_polygon = detect_lane_area(frame)

    annotated_frame, collision_warning = process_detections(results, lane_polygon, M)

    warning_counter = min(warning_counter + 5, 30) if collision_warning else max(warning_counter - 1, 0)

    if warning_counter > 0:
        h, w = frame.shape[:2]
        draw_text_with_background(annotated_frame, "⚠ Forward Collision Warning ⚠",
                                  (int(w * 0.15), 60),
                                  cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

    cv2.polylines(annotated_frame, [lane_polygon], isClosed=True, color=(0, 255, 255), thickness=2)

    lane_poly_np = np.array([lane_polygon], dtype=np.float32)
    warped_lane = cv2.perspectiveTransform(lane_poly_np, M)
    reprojected_lane = cv2.perspectiveTransform(warped_lane, np.linalg.inv(M))
    cv2.polylines(annotated_frame, [np.int32(reprojected_lane)], isClosed=True, color=(0, 150, 255), thickness=2)

    fps = 1.0 / (time.time() - start_time)
    cv2.putText(annotated_frame, f"FPS: {fps:.1f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    out.write(annotated_frame)
    cv2.imshow("YOLO + Collision Warning + Warped Lane", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 33
#      25 CLASS_COLORS = {
#      26     2: (0, 255, 0),
#      27     5: (255, 255, 0),
#      28     7: (255, 0, 255)
#      29 }
#      31 VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())
# ---> 33 model = YOLO("/home/hkit/Downloads/3team3/best.pt")
#      35 cap = cv2.VideoCapture("/home/hkit/Downloads/3team3/서성네거리 11중 추돌사고 당시 블랙박스 영상.mp4")
#      36 out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\models\yolo\model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      81         from ultralytics import RTDETR
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\engine\model.py:151, in Model.__init__(self, model, task, verbose)
#     149     self._new(model, task=task, verbose=verbose)
#     150 else:
# --> 151     self._load(model, task=task)
#     153 # Delete super().training for accessing self.model.training
#     154 del self.training
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\engine\model.py:295, in Model._load(self, weights, task)
#     292 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     294 if str(weights).rpartition(".")[-1] == "pt":
# --> 295     self.model, self.ckpt = attempt_load_one_weight(weights)
#     296     self.task = self.model.task
#     297     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\nn\tasks.py:1549, in attempt_load_one_weight(weight, device, inplace, fuse)
#    1535 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#    1536     """
#    1537     Load a single model weights.
#    1538
#    (...)   1547         ckpt (dict): Model checkpoint dictionary.
#    1548     """
# -> 1549     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1550     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1551     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\nn\tasks.py:1447, in torch_safe_load(weight, safe_only)
#    1445                 ckpt = torch.load(f, pickle_module=safe_pickle)
#    1446         else:
# -> 1447             ckpt = torch.load(file, map_location="cpu")
#    1449 except ModuleNotFoundError as e:  # e.name is missing module name
#    1450     if e.name == "models":
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\ultralytics\utils\patches.py:117, in torch_load(*args, **kwargs)
#     114 if TORCH_1_13 and "weights_only" not in kwargs:
#     115     kwargs["weights_only"] = False
# --> 117 return _torch_load(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\torch\serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1316 if "encoding" not in pickle_load_args.keys():
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#    1324         orig_position = opened_file.tell()
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\torch\serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# File c:\Users\USER\anaconda3\envs\gai\Lib\site-packages\torch\serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\home\\hkit\\Downloads\\3team3\\best.pt'

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import time

# 설정 상수
CONF_THRESHOLD = 0.3
DIST_THRESHOLD = 1200  # cm
FOCAL_LENGTH = 400
RESIZE_WIDTH = 1280
RESIZE_HEIGHT = 720

LANE_POLYGON_VERTICES = [
    (0.2, 1.0), (0.8, 1.0), (0.6, 0.6), (0.4, 0.6)
]

KNOWN_HEIGHTS = {
    0: 160,  # 사람
    2: 150,  # 자동차
    3: 100,  # 오토바이
    5: 350,  # 버스
    7: 350   # 트럭
}

CLASS_COLORS = {
    2: (0, 255, 0),
    5: (255, 255, 0),
    7: (255, 0, 255)
}

VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())

model = YOLO("/home/hkit/Downloads/3team3/best.pt")

cap = cv2.VideoCapture("joohyeok.mp4")
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))

def detect_lane_area(frame):
    h, w = frame.shape[:2]
    polygon = np.array([[(int(w * x), int(h * y)) for (x, y) in LANE_POLYGON_VERTICES]])
    return polygon[0]

def get_perspective_transform_matrix(frame):
    h, w = frame.shape[:2]
    src_pts = np.float32([[w * x, h * y] for (x, y) in LANE_POLYGON_VERTICES])
    dst_pts = np.float32([[0, h], [w, h], [w, 0], [0, 0]])
    return cv2.getPerspectiveTransform(src_pts, dst_pts)

def draw_text_with_background(img, text, org, font, scale, color, thickness):
    (tw, th), base = cv2.getTextSize(text, font, scale, thickness)
    x, y = org
    cv2.rectangle(img, (x, y - th - base), (x + tw + 4, y + base), (0, 0, 0), -1)
    cv2.putText(img, text, org, font, scale, color, thickness)

def process_detections(results, lane_polygon, M):
    collision_warning = False
    annotated_frame = results[0].plot()

    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf.item())
        class_id = int(box.cls.item())
        pixel_height = y2 - y1

        if pixel_height < 5:
            continue

        center_y = y2 - 0.2 * (y2 - y1)
        center = np.array([[(x1 + x2) / 2, center_y]], dtype=np.float32)
        is_inside = cv2.pointPolygonTest(lane_polygon, tuple(center[0]), False)

        if class_id in VALID_CLASS_IDS and conf > CONF_THRESHOLD and pixel_height > 20:
            center_warped = cv2.perspectiveTransform(np.array([center]), M)[0][0]
            known_height = KNOWN_HEIGHTS.get(class_id, 170)
            dist_pixel = (known_height * FOCAL_LENGTH) / pixel_height
            warped_y = center_warped[1]
            dist_y = DIST_THRESHOLD * (1 - warped_y / RESIZE_HEIGHT)
            dist_y = max(50, dist_y)

            distance_cm = dist_pixel * 0.7 + dist_y * 0.3
            distance_m = distance_cm / 100

            # 원본 경고 조건 그대로 유지
            if distance_cm < DIST_THRESHOLD:
                collision_warning = True
                box_color = (0, 0, 255)
                thickness = 3
            else:
                box_color = CLASS_COLORS.get(class_id, (255, 255, 255))
                thickness = 2

            # 바운딩 박스 및 거리 표시 (항상 표시)
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, thickness)
            dist_label = f"{distance_m:.1f}m"
            class_label = model.model.names[class_id] if hasattr(model.model, 'names') else str(class_id)
            draw_text_with_background(annotated_frame, dist_label, (x1, y2 + 25),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)

            # 중심점 표시
            cv2.circle(annotated_frame, (int(center_warped[0]), int(center_warped[1])),
                       5, (255, 0, 0), -1)

    return annotated_frame, collision_warning

warning_counter = 3
M = None

while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (RESIZE_WIDTH, RESIZE_HEIGHT))

    if M is None:
        M = get_perspective_transform_matrix(frame)

    results = model(frame, conf=CONF_THRESHOLD, iou=0.5)
    lane_polygon = detect_lane_area(frame)

    annotated_frame, collision_warning = process_detections(results, lane_polygon, M)

    warning_counter = min(warning_counter + 5, 30) if collision_warning else max(warning_counter - 1, 0)

    if warning_counter > 0:
        h, w = frame.shape[:2]
        draw_text_with_background(annotated_frame, "⚠ Forward Collision Warning ⚠",
                                  (int(w * 0.15), 60),
                                  cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

    cv2.polylines(annotated_frame, [lane_polygon], isClosed=True, color=(0, 255, 255), thickness=2)

    lane_poly_np = np.array([lane_polygon], dtype=np.float32)
    warped_lane = cv2.perspectiveTransform(lane_poly_np, M)
    reprojected_lane = cv2.perspectiveTransform(warped_lane, np.linalg.inv(M))
    cv2.polylines(annotated_frame, [np.int32(reprojected_lane)], isClosed=True, color=(0, 150, 255), thickness=2)

    fps = 1.0 / (time.time() - start_time)
    cv2.putText(annotated_frame, f"FPS: {fps:.1f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    out.write(annotated_frame)
    cv2.imshow("YOLO + Collision Warning + Warped Lane", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 1 bus- truck, 2 cars, 128.2ms
# Speed: 4.2ms preprocess, 128.2ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 608)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/hkit/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# 0: 352x608 1 bus- truck, 2 cars, 94.9ms
# Speed: 13.6ms preprocess, 94.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 83.6ms
# Speed: 2.7ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 69.3ms
# Speed: 2.7ms preprocess, 69.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 83.1ms
# Speed: 2.7ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 70.7ms
# Speed: 2.8ms preprocess, 70.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 79.5ms
# Speed: 3.1ms preprocess, 79.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 78.5ms
# Speed: 4.2ms preprocess, 78.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 62.1ms
# Speed: 2.2ms preprocess, 62.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 67.4ms
# Speed: 2.4ms preprocess, 67.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 85.4ms
# Speed: 4.6ms preprocess, 85.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 78.1ms
# Speed: 3.0ms preprocess, 78.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 77.5ms
# Speed: 3.2ms preprocess, 77.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 57.6ms
# Speed: 4.7ms preprocess, 57.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 4 cars, 91.3ms
# Speed: 7.3ms preprocess, 91.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 2 cars, 67.3ms
# Speed: 2.2ms preprocess, 67.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 2 cars, 65.3ms
# Speed: 3.4ms preprocess, 65.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 2 cars, 62.4ms
# Speed: 4.4ms preprocess, 62.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 2 cars, 57.7ms
# Speed: 6.1ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 61.8ms
# Speed: 2.6ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 59.7ms
# Speed: 2.1ms preprocess, 59.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 65.7ms
# Speed: 2.4ms preprocess, 65.7ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 65.4ms
# Speed: 7.9ms preprocess, 65.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 64.2ms
# Speed: 7.0ms preprocess, 64.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 63.4ms
# Speed: 2.3ms preprocess, 63.4ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 68.5ms
# Speed: 7.0ms preprocess, 68.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 59.6ms
# Speed: 6.6ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 57.5ms
# Speed: 7.1ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 62.9ms
# Speed: 4.5ms preprocess, 62.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 64.9ms
# Speed: 2.3ms preprocess, 64.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 65.9ms
# Speed: 2.3ms preprocess, 65.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 65
ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 63.6ms
# Speed: 2.8ms preprocess, 63.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 58.7ms
# Speed: 4.5ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 57.2ms
# Speed: 4.1ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 62.8ms
# Speed: 4.0ms preprocess, 62.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 59.5ms
# Speed: 5.6ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 cars, 58.2ms
# Speed: 4.7ms preprocess, 58.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)

# %%
## 아무 차선인식 대입해보고 한 것##

from ultralytics import YOLO
import cv2
import numpy as np
import time

# 설정 상수
CONF_THRESHOLD = 0.3
DIST_THRESHOLD = 1200  # cm
FOCAL_LENGTH = 400
RESIZE_WIDTH = 1280
RESIZE_HEIGHT = 720

LANE_POLYGON_VERTICES = [
    (0.2, 1.0), (0.8, 1.0), (0.6, 0.6), (0.4, 0.6)
]

KNOWN_HEIGHTS = {
    0: 160,  # 사람
    2: 150,  # 자동차
    3: 100,  # 오토바이
    5: 350,  # 버스
    7: 350   # 트럭
}

CLASS_COLORS = {
    2: (0, 255, 0),
    5: (255, 255, 0),
    7: (255, 0, 255)
}

VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())

model = YOLO("/home/hkit/Downloads/3team3/best.pt")

cap = cv2.VideoCapture("police.mp4")
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))

# 개선된 차선 인식 함수 (B안)
def detect_lane_area(frame):
    h, w = frame.shape[:2]
    roi = frame[int(h * 0.6):, :]
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    white_mask = cv2.inRange(hsv, np.array([0, 0, 200]), np.array([180, 40, 255]))
    yellow_mask = cv2.inRange(hsv, np.array([10, 80, 100]), np.array([40, 255, 255]))
    mask = cv2.bitwise_or(white_mask, yellow_mask)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    edges = cv2.Canny(mask, 50, 120)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=60, minLineLength=50, maxLineGap=80)

    points = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            points.append((x1, y1 + int(h * 0.6)))
            points.append((x2, y2 + int(h * 0.6)))

    if len(points) < 6:
        return None

    hull = cv2.convexHull(np.array(points))
    return hull.reshape(-1, 2)

def get_perspective_transform_matrix(frame):
    h, w = frame.shape[:2]
    src_pts = np.float32([[w * x, h * y] for (x, y) in LANE_POLYGON_VERTICES])
    dst_pts = np.float32([[0, h], [w, h], [w, 0], [0, 0]])
    return cv2.getPerspectiveTransform(src_pts, dst_pts)

def draw_text_with_background(img, text, org, font, scale, color, thickness):
    (tw, th), base = cv2.getTextSize(text, font, scale, thickness)
    x, y = org
    cv2.rectangle(img, (x, y - th - base), (x + tw + 4, y + base), (0, 0, 0), -1)
    cv2.putText(img, text, org, font, scale, color, thickness)

def process_detections(results, lane_polygon, M):
    collision_warning = False
    annotated_frame = results[0].plot()

    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf.item())
        class_id = int(box.cls.item())
        pixel_height = y2 - y1

        if pixel_height < 5:
            continue

        center_y = y2 - 0.2 * (y2 - y1)
        center = np.array([[(x1 + x2) / 2, center_y]], dtype=np.float32)
        is_inside = cv2.pointPolygonTest(lane_polygon, tuple(center[0]), False)

        if class_id in VALID_CLASS_IDS and conf > CONF_THRESHOLD and pixel_height > 20:
            center_warped = cv2.perspectiveTransform(np.array([center]), M)[0][0]
            known_height = KNOWN_HEIGHTS.get(class_id, 170)
            dist_pixel = (known_height * FOCAL_LENGTH) / pixel_height
            warped_y = center_warped[1]
            dist_y = DIST_THRESHOLD * (1 - warped_y / RESIZE_HEIGHT)
            dist_y = max(50, dist_y)

            distance_cm = dist_pixel * 0.7 + dist_y * 0.3
            distance_m = distance_cm / 100

            if distance_cm < DIST_THRESHOLD:
                collision_warning = True
                box_color = (0, 0, 255)
                thickness = 3
            else:
                box_color = CLASS_COLORS.get(class_id, (255, 255, 255))
                thickness = 2

            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, thickness)
            dist_label = f"{distance_m:.1f}m"
            class_label = model.model.names[class_id] if hasattr(model.model, 'names') else str(class_id)
            draw_text_with_background(annotated_frame, dist_label, (x1, y2 + 25),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
            cv2.circle(annotated_frame, (int(center_warped[0]), int(center_warped[1])), 5, (255, 0, 0), -1)

    return annotated_frame, collision_warning

# === 메인 루프 ===
warning_counter = 3
M = None

while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (RESIZE_WIDTH, RESIZE_HEIGHT))

    if M is None:
        M = get_perspective_transform_matrix(frame)

    results = model(frame, conf=CONF_THRESHOLD, iou=0.5)
    lane_polygon = detect_lane_area(frame)

    if lane_polygon is not None:
        annotated_frame, collision_warning = process_detections(results, lane_polygon, M)

        warning_counter = min(warning_counter + 5, 30) if collision_warning else max(warning_counter - 1, 0)

        if warning_counter > 0:
            draw_text_with_background(annotated_frame, "!!! Forward Collision Warning !!!",
                                      (int(RESIZE_WIDTH * 0.15), 60),
                                      cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 255), 3)

        cv2.polylines(annotated_frame, [lane_polygon], isClosed=True, color=(0, 255, 255), thickness=2)

        lane_poly_np = np.array([lane_polygon], dtype=np.float32)
        warped_lane = cv2.perspectiveTransform(lane_poly_np, M)
        reprojected_lane = cv2.perspectiveTransform(warped_lane, np.linalg.inv(M))
        cv2.polylines(annotated_frame, [np.int32(reprojected_lane)], isClosed=True, color=(0, 150, 255), thickness=2)

    else:
        annotated_frame = results[0].plot()
        warning_counter = max(warning_counter - 1, 0)

    fps = 1.0 / (time.time() - start_time)
    cv2.putText(annotated_frame, f"FPS: {fps:.1f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    out.write(annotated_frame)
    cv2.imshow("YOLO + Collision Warning + Warped Lane", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 2 bus- trucks, 4 cars, 214.2ms
# Speed: 8.2ms preprocess, 214.2ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 608)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/hkit/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# 0: 352x608 2 bus- trucks, 3 cars, 87.7ms
# Speed: 5.3ms preprocess, 87.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 3 cars, 154.2ms
# Speed: 23.6ms preprocess, 154.2ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 4 cars, 104.1ms
# Speed: 6.8ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 3 cars, 119.6ms
# Speed: 8.2ms preprocess, 119.6ms inference, 6.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 2 bus- trucks, 6 cars, 88.8ms
# Speed: 2.6ms preprocess, 88.8ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 90.2ms
# Speed: 6.4ms preprocess, 90.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 102.1ms
# Speed: 2.3ms preprocess, 102.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 88.2ms
# Speed: 12.8ms preprocess, 88.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 4 cars, 96.9ms
# Speed: 8.6ms preprocess, 96.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 111.9ms
# Speed: 8.2ms preprocess, 111.9ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 89.3ms
# Speed: 11.5ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 88.7ms
# Speed: 2.7ms preprocess, 88.7ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 91.8ms
# Speed: 10.8ms preprocess, 91.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 87.9ms
# Speed: 9.4ms preprocess, 87.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 88.7ms
# Speed: 3.4ms preprocess, 88.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 102.4ms
# Speed: 6.4ms preprocess, 102.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 77.1ms
# Speed: 3.2ms preprocess, 77.1ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 79.6ms
# Speed: 14.5ms preprocess, 79.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 82.3ms
# Speed: 5.3ms preprocess, 82.3ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 84.2ms
# Speed: 8.6ms preprocess, 84.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 100.4ms
# Speed: 9.5ms preprocess, 100.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 93.5ms
# Speed: 3.6ms preprocess, 93.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 69.3ms
# Speed: 6.2ms preprocess, 69.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 79.2ms
# Speed: 4.6ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 bus- truck, 3 cars, 81.0ms
# Speed: 10.4ms preprocess, 81.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 99.6ms
# Speed: 4.8ms preprocess, 99.6ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 79.8ms
# Speed: 4.6ms preprocess, 79.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 107.0ms
# Speed: 6.7ms preprocess, 107.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 3 cars, 76.3ms
# Speed: 4.9ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 80.2ms
# Speed: 7.9ms preprocess, 80.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 77.9ms
# Speed: 5.2ms preprocess, 77.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 75.0ms
# Speed: 12.1ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 265.4ms
# Speed: 4.5ms preprocess, 265.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 79.4ms
# Speed: 7.3ms preprocess, 79.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 82.2ms
# Speed: 5.9ms preprocess, 82.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 79.0ms
# Speed: 4.9ms preprocess, 79.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 80.2ms
# Speed: 3.8ms preprocess, 80.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 80.5ms
# Speed: 3.4ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 5 cars, 79.7ms
# Speed: 5.2ms preprocess, 79.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 84.8ms
# Speed: 8.4ms preprocess, 84.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 80.3ms
# Speed: 4.8ms preprocess, 80.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 81.3ms
# Speed: 14.6ms preprocess, 81.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 4 cars, 86.9ms
# Speed: 3.8ms preprocess, 86.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)

# %%
import time
import cv2
import numpy as np
from ultralytics import YOLO

# 설정 상수
CONF_THRESHOLD = 0.3
DIST_THRESHOLD = 1200  # cm
FOCAL_LENGTH = 400
RESIZE_WIDTH = 1280
RESIZE_HEIGHT = 720

LANE_POLYGON_VERTICES = [
    (0.2, 1.0), (0.8, 1.0), (0.6, 0.6), (0.4, 0.6)
]

KNOWN_HEIGHTS = {
    0: 160,  # 사람
    2: 150,  # 자동차
    3: 100,  # 오토바이
    5: 350,  # 버스
    7: 350   # 트럭
}

CLASS_COLORS = {
    2: (0, 255, 0),
    5: (255, 255, 0),
    7: (255, 0, 255)
}

VALID_CLASS_IDS = list(KNOWN_HEIGHTS.keys())
from pathlib import Path

resource_path = Path("..") / "resource"
model = YOLO(resource_path / "best.pt")
video_path = resource_path/ "harder_challenge_video.mp4"

cap = cv2.VideoCapture(video_path)
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 30, (RESIZE_WIDTH, RESIZE_HEIGHT))

# 경고 배너 이미지 불러오기 및 스케일 50% 축소
warning_banner = cv2.imread(resource_path /"warning_banner.png", cv2.IMREAD_UNCHANGED)
if warning_banner is not None:
    warning_banner = cv2.resize(warning_banner, (0, 0), fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)

# ======= 유틸 함수 =======

def draw_text_with_background(img, text, org, font, scale, color, thickness):
    (tw, th), base = cv2.getTextSize(text, font, scale, thickness)
    x, y = org
    cv2.rectangle(img, (x, y - th - base), (x + tw + 4, y + base), (0, 0, 0), -1)
    cv2.putText(img, text, org, font, scale, color, thickness)

def overlay_warning_banner(frame, banner_img, x, y):
    bh, bw = banner_img.shape[:2]
    fh, fw = frame.shape[:2]

    # 배너가 프레임 바깥일 경우 그리지 않음 (완전 밖으로 나가면 return)
    if x >= fw or x + bw <= 0:
        return
    if y >= fh or y + bh <= 0:
        return

    # 배너가 화면 밖으로 살짝 나가도 일부만 그릴 수 있도록 처리
    x1_frame = max(x, 0)
    y1_frame = max(y, 0)
    x1_banner = max(0, -x)
    y1_banner = max(0, -y)

    x2_frame = min(fw, x + bw)
    y2_frame = min(fh, y + bh)
    x2_banner = x2_frame - x
    y2_banner = y2_frame - y

    if banner_img.shape[2] == 4:  # 알파 채널 처리
        alpha = banner_img[y1_banner:y2_banner, x1_banner:x2_banner, 3] / 255.0
        for c in range(3):  # BGR
            frame[y1_frame:y2_frame, x1_frame:x2_frame, c] = (
                frame[y1_frame:y2_frame, x1_frame:x2_frame, c] * (1 - alpha) + 
                banner_img[y1_banner:y2_banner, x1_banner:x2_banner, c] * alpha
            ).astype(np.uint8)
    else:
        frame[y1_frame:y2_frame, x1_frame:x2_frame] = banner_img[y1_banner:y2_banner, x1_banner:x2_banner]


def detect_lane_area(frame):
    h, w = frame.shape[:2]
    roi = frame[int(h * 0.6):, :]
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)

    white_mask = cv2.inRange(hsv, np.array([0, 0, 200]), np.array([180, 40, 255]))
    yellow_mask = cv2.inRange(hsv, np.array([10, 80, 100]), np.array([40, 255, 255]))
    mask = cv2.bitwise_or(white_mask, yellow_mask)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)

    edges = cv2.Canny(mask, 50, 120)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=60, minLineLength=50, maxLineGap=80)

    points = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            points.append((x1, y1 + int(h * 0.6)))
            points.append((x2, y2 + int(h * 0.6)))

    if len(points) < 6:
        return None

    hull = cv2.convexHull(np.array(points))
    return hull.reshape(-1, 2)

def get_perspective_transform_matrix(frame):
    h, w = frame.shape[:2]
    src_pts = np.float32([[w * x, h * y] for (x, y) in LANE_POLYGON_VERTICES])
    dst_pts = np.float32([[0, h], [w, h], [w, 0], [0, 0]])
    return cv2.getPerspectiveTransform(src_pts, dst_pts)

def process_detections(results, lane_polygon, M):
    collision_warning = False
    annotated_frame = results[0].plot()

    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf.item())
        class_id = int(box.cls.item())
        pixel_height = y2 - y1

        if pixel_height < 5:
            continue

        center_y = y2 - 0.2 * (y2 - y1)
        center = np.array([[(x1 + x2) / 2, center_y]], dtype=np.float32)
        is_inside = cv2.pointPolygonTest(lane_polygon, tuple(center[0]), False)

        if class_id in VALID_CLASS_IDS and conf > CONF_THRESHOLD and pixel_height > 20:
            center_warped = cv2.perspectiveTransform(np.array([center]), M)[0][0]
            known_height = KNOWN_HEIGHTS.get(class_id, 170)
            dist_pixel = (known_height * FOCAL_LENGTH) / pixel_height
            warped_y = center_warped[1]
            dist_y = DIST_THRESHOLD * (1 - warped_y / RESIZE_HEIGHT)
            dist_y = max(50, dist_y)

            distance_cm = dist_pixel * 0.7 + dist_y * 0.3
            distance_m = distance_cm / 100

            if distance_cm < DIST_THRESHOLD:
                collision_warning = True
                box_color = (0, 0, 255)
                thickness = 3
            else:
                box_color = CLASS_COLORS.get(class_id, (255, 255, 255))
                thickness = 2

            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), box_color, thickness)
            dist_label = f"{distance_m:.1f}m"
            class_label = model.model.names[class_id] if hasattr(model.model, 'names') else str(class_id)
            draw_text_with_background(annotated_frame, dist_label, (x1, y2 + 25),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)
            cv2.circle(annotated_frame, (int(center_warped[0]), int(center_warped[1])), 5, (255, 0, 0), -1)

    return annotated_frame, collision_warning

# === 메인 루프 ===
warning_counter = 3
M = None

while cap.isOpened():
    start_time = time.time()
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.resize(frame, (RESIZE_WIDTH, RESIZE_HEIGHT))

    if M is None:
        M = get_perspective_transform_matrix(frame)

    results = model(frame, conf=CONF_THRESHOLD, iou=0.5)
    lane_polygon = detect_lane_area(frame)

    if lane_polygon is not None:
        annotated_frame, collision_warning = process_detections(results, lane_polygon, M)

        warning_counter = min(warning_counter + 5, 30) if collision_warning else max(warning_counter - 1, 0)

        if warning_counter > 0 and warning_banner is not None:
            banner_width = warning_banner.shape[1]
            x_pos = int((RESIZE_WIDTH - banner_width) / 2)  # 중앙 정렬
            y_pos = -90
            overlay_warning_banner(annotated_frame, warning_banner, x_pos, y_pos)


        cv2.polylines(annotated_frame, [lane_polygon], isClosed=True, color=(0, 255, 255), thickness=2)

        lane_poly_np = np.array([lane_polygon], dtype=np.float32)
        warped_lane = cv2.perspectiveTransform(lane_poly_np, M)
        reprojected_lane = cv2.perspectiveTransform(warped_lane, np.linalg.inv(M))
        cv2.polylines(annotated_frame, [np.int32(reprojected_lane)], isClosed=True, color=(0, 150, 255), thickness=2)

    else:
        annotated_frame = results[0].plot()
        warning_counter = max(warning_counter - 1, 0)

    fps = 1.0 / (time.time() - start_time)
    cv2.putText(annotated_frame, f"FPS: {fps:.1f}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 255), 2)

    out.write(annotated_frame)
    cv2.imshow("YOLO + Collision Warning + Warped Lane", annotated_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 352x608 (no detections), 81.5ms
# Speed: 2.3ms preprocess, 81.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.7ms
# Speed: 2.4ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.2ms
# Speed: 1.7ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.4ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.5ms
# Speed: 1.8ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.7ms
# Speed: 1.8ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.0ms
# Speed: 1.6ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.1ms
# Speed: 1.8ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.6ms
# Speed: 1.5ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.6ms
# Speed: 1.6ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.2ms
# Speed: 1.8ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.0ms
# Speed: 1.6ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.1ms
# Speed: 1.9ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.4ms
# Speed: 1.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.4ms
# Speed: 1.5ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.3ms
# Speed: 1.6ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.0ms
# Speed: 1.4ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 48.0ms
# Speed: 12.1ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.4ms
# Speed: 1.7ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.9ms
# Speed: 1.7ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.3ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.5ms
# Speed: 1.5ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.7ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.2ms
# Speed: 1.7ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.0ms
# Speed: 1.8ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.8ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.9ms
# Speed: 1.6ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.7ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42
ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.6ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 43.0ms
# Speed: 1.8ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 74.3ms
# Speed: 1.8ms preprocess, 74.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 40.4ms
# Speed: 1.6ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 49.2ms
# Speed: 2.1ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 48.8ms
# Speed: 2.1ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.1ms
# Speed: 1.4ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 45.9ms
# Speed: 6.8ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.4ms
# Speed: 1.5ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.0ms
# Speed: 2.0ms preprocess, 41.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 46.3ms
# Speed: 1.8ms preprocess, 46.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.0ms
# Speed: 1.5ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 1 motorcycle, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 1 motorcycle, 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 motorcycle, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.9ms
# Speed: 3.1ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.6ms
# Speed: 1.6ms preprocess, 41.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.2ms
# Speed: 1.9ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.5ms
# Speed: 1.8ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.0ms
# Speed: 1.8ms preprocess, 41.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.9ms
# Speed: 1.5ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.2ms
# Speed: 1.8ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.3ms
# Speed: 1.8ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.7ms
# Speed: 1.9ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.5ms
# Speed: 1.6ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.8ms
# Speed: 1.7ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.4ms
# Speed: 1.6ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.8ms
# Speed: 1.5ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.0ms
# Speed: 1.9ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 motorcycle, 39.6ms
# Speed: 3.9ms preprocess, 39.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.1ms
# Speed: 1.4ms preprocess, 39.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 animal, 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 animal, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 animal, 1 human, 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.3ms
# Speed: 1.9ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 animal, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.1ms
# Speed: 1.5ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.5ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 48.5ms
# Speed: 6.1ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 39.0ms
# Speed: 1.9ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 39.5ms
# Speed: 1.8ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 1 car, 38.1ms
# ...
#
# 0: 352x608 (no detections), 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 38.8ms
# Speed: 1.8ms preprocess, 38.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.6ms
# Speed: 1.6ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 73.7ms
# Speed: 1.6ms preprocess, 73.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.1ms
# Speed: 1.5ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.9ms
# Speed: 1.5ms preprocess, 41.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.7ms
# Speed: 1.4ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 46.5ms
# Speed: 5.8ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.6ms
# Speed: 1.6ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 608)
#
# 0: 352x608 (no detections), 39.9ms
# Speed: 1